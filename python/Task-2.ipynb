# %% [markdown]
# ![image.png](attachment:dd9d7754-acdf-4104-9bed-eaec98c5cbb1.png)

# %%
# class Solution:
    def runningSum(self, nums: List[int]) -> List[int]:

        return [sum(nums[:i+1]) for i in range(len(nums))]

# %% [markdown]
# ![image.png](attachment:b054f4f9-ec15-4c90-a44d-f7614c5b179b.png)

# %%
class Solution:
    def shuffle(self, nums: List[int], n: int) -> List[int]:
        return [nums[i//2 + n*(i%2)] for i in range(2*n)]

# %% [markdown]
# ![image.png](attachment:9331fff4-3c13-45dc-903d-c8253cec3eb6.png)

# %%
class Solution:
    def kidsWithCandies(self, candies: List[int], extraCandies: int) -> List[bool]:
        return [c + extraCandies >= max(candies) for c in candies]
